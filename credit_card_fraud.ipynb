# %% [markdown]
# <a href="https://colab.research.google.com/github/developr4u/practice/blob/master/credit_card_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-rc0
# Out:
# Collecting tensorflow==2.0.0-rc0
#   Downloading https://files.pythonhosted.org/packages/fb/4b/77f0965ec7e8a76d3dcd6a22ca8bbd2b934cd92c4ded43fef6bea5ff3258/tensorflow-2.0.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (86.3MB)
#      |████████████████████████████████| 86.3MB 371kB/s
# Collecting tb-nightly<1.15.0a20190807,>=1.15.0a20190806 (from tensorflow==2.0.0-rc0)
#   Downloading https://files.pythonhosted.org/packages/bc/88/24b5fb7280e74c7cf65bde47c171547fd02afb3840cff41bcbe9270650f5/tb_nightly-1.15.0a20190806-py3-none-any.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 38.6MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.1.7)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.2.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (3.0.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (3.7.1)
# Collecting tf-estimator-nightly<1.14.0.dev2019080602,>=1.14.0.dev2019080601 (from tensorflow==2.0.0-rc0)
#   Downloading https://files.pythonhosted.org/packages/21/28/f2a27a62943d5f041e4a6fd404b2d21cb7c59b2242a4e73b03d9ba166552/tf_estimator_nightly-1.14.0.dev2019080601-py2.py3-none-any.whl (501kB)
#      |████████████████████████████████| 501kB 57.7MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.11.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.8.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.33.6)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.16.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (41.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (0.15.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0.0-rc0) (2.8.0)
# Installing collected packages: tb-nightly, tf-estimator-nightly, tensorflow
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed tb-nightly-1.15.0a20190806 tensorflow-2.0.0rc0 tf-estimator-nightly-1.14.0.dev2019080601

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization,Conv1D,MaxPool1D
from tensorflow.keras.optimizers import Adam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

# %%
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud = data[data['Class']==1]
non_fraud = data[data['Class']==0]
fraud.shape,non_fraud.shape
# Out:
# ((492, 31), (284315, 31))

# %%
non_fraud = non_fraud.sample(492)

# %%
non_fraud.shape,fraud.shape
# Out:
# ((492, 31), (492, 31))

# %%
data = fraud.append(non_fraud,ignore_index=True)
data
# Out:
#          Time        V1         V2  ...       V28   Amount  Class
# 0       406.0 -2.312227   1.951992  ... -0.143276     0.00      1
# 1       472.0 -3.043541  -3.157307  ...  0.035764   529.00      1
# 2      4462.0 -2.303350   1.759247  ... -0.153029   239.93      1
# 3      6986.0 -4.397974   1.358367  ...  0.849573    59.00      1
# 4      7519.0  1.234235   3.019740  ...  0.146793     1.00      1
# 5      7526.0  0.008430   4.137837  ...  0.513574     1.00      1
# 6      7535.0  0.026779   4.132464  ...  0.496699     1.00      1
# 7      7543.0  0.329594   3.712889  ...  0.404474     1.00      1
# 8      7551.0  0.316459   3.809076  ...  0.402528     1.00      1
# 9      7610.0  0.725646   2.300894  ...  0.099372     1.00      1
# 10     7672.0  0.702710   2.426433  ...  0.129305     1.00      1
# 11     7740.0  1.023874   2.001485  ...  0.020206     1.00      1
# 982   84529.0  0.241708  -1.891701  ...  0.092496   404.86      0
# 983  164036.0  1.078629  -3.309599  ...  0.037064   514.90      0
#
# [984 rows x 31 columns]

# %%
x = data.drop('Class',axis=1)
x.head()
# Out:
#      Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 0   406.0 -2.312227  1.951992 -1.609851  ...  0.177840  0.261145 -0.143276    0.00
# 1   472.0 -3.043541 -3.157307  1.088463  ... -0.145362 -0.252773  0.035764  529.00
# 2  4462.0 -2.303350  1.759247 -0.359745  ... -0.542628  0.039566 -0.153029  239.93
# 3  6986.0 -4.397974  1.358367 -2.592844  ... -0.657488 -0.827136  0.849573   59.00
# 4  7519.0  1.234235  3.019740 -4.304597  ...  0.566797 -0.010016  0.146793    1.00
#
# [5 rows x 30 columns]

# %%
y = data['Class']
y.value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0,stratify=y)
x_train.shape,x_test.shape
# Out:
# ((787, 30), (197, 30))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
x_train = x_train.reshape(787,30,1)
x_test = x_test.reshape(197,30,1)
x_train.shape,x_test.shape
# Out:
# ((787, 30, 1), (197, 30, 1))

# %%
model = Sequential()
model.add(Conv1D(32,(2),activation='relu',input_shape=(30,1)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv1D(64,(2),activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 29, 32)            96
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 29, 32)            128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 29, 32)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 28, 64)            4160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28, 64)            256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 28, 64)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1792)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                114752
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.00001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=30,validation_data=(x_test,y_test),verbose=1)
# Out:
# Train on 787 samples, validate on 197 samples
# Epoch 1/30
# 787/787 [==============================] - 2s 2ms/sample - loss: 1.0794 - accuracy: 0.4956 - val_loss: 0.6924 - val_accuracy: 0.4924
# Epoch 2/30
# 787/787 [==============================] - 0s 371us/sample - loss: 0.9468 - accuracy: 0.5388 - val_loss: 0.6890 - val_accuracy: 0.5584
# Epoch 3/30
# 787/787 [==============================] - 0s 349us/sample - loss: 0.8487 - accuracy: 0.5947 - val_loss: 0.6817 - val_accuracy: 0.5939
# Epoch 4/30
# 787/787 [==============================] - 0s 352us/sample - loss: 0.7477 - accuracy: 0.6036 - val_loss: 0.6716 - val_accuracy: 0.5787
# Epoch 5/30
# 787/787 [==============================] - 0s 341us/sample - loss: 0.7363 - accuracy: 0.6302 - val_loss: 0.6582 - val_accuracy: 0.5990
# Epoch 6/30
# 787/787 [==============================] - 0s 362us/sample - loss: 0.6916 - accuracy: 0.6595 - val_loss: 0.6440 - val_accuracy: 0.5990
# Epoch 7/30
# 787/787 [==============================] - 0s 356us/sample - loss: 0.6645 - accuracy: 0.6760 - val_loss: 0.6279 - val_accuracy: 0.6193
# Epoch 8/30
# 787/787 [==============================] - 0s 339us/sample - loss: 0.5985 - accuracy: 0.7065 - val_loss: 0.6098 - val_accuracy: 0.6447
# Epoch 9/30
# 787/787 [==============================] - 0s 336us/sample - loss: 0.5673 - accuracy: 0.7344 - val_loss: 0.5897 - val_accuracy: 0.6497
# Epoch 10/30
# 787/787 [==============================] - 0s 350us/sample - loss: 0.5450 - accuracy: 0.7497 - val_loss: 0.5686 - val_accuracy: 0.6701
# Epoch 11/30
# 787/787 [==============================] - 0s 343us/sample - loss: 0.5508 - accuracy: 0.7395 - val_loss: 0.5462 - val_accuracy: 0.6802
# Epoch 12/30
# 787/787 [==============================] - 0s 338us/sample - loss: 0.5079 - accuracy: 0.7649 - val_loss: 0.5237 - val_accuracy: 0.7107
# Epoch 13/30
# 787/787 [==============================] - 0s 351us/sample - loss: 0.4870 - accuracy: 0.7789 - val_loss: 0.5022 - val_accuracy: 0.7259
# Epoch 14/30
# 787/787 [==============================] - 0s 338us/sample - loss: 0.5001 - accuracy: 0.7776 - val_loss: 0.4811 - val_accuracy: 0.7360
# Epoch 15/30
# 787/787 [==============================] - 0s 357us/sample - loss: 0.4391 - accuracy: 0.8145 - val_loss: 0.4631 - val_accuracy: 0.7614
# Epoch 16/30
# 787/787 [==============================] - 0s 360us/sample - loss: 0.4381 - accuracy: 0.8043 - val_loss: 0.4482 - val_accuracy: 0.7817
# Epoch 17/30
# 787/787 [==============================] - 0s 375us/sample - loss: 0.4480 - accuracy: 0.8069 - val_loss: 0.4331 - val_accuracy: 0.7970
# Epoch 18/30
# 787/787 [==============================] - 0s 353us/sample - loss: 0.4153 - accuracy: 0.8158 - val_loss: 0.4195 - val_accuracy: 0.8325
# Epoch 19/30
# 787/787 [==============================] - 0s 370us/sample - loss: 0.4120 - accuracy: 0.8310 - val_loss: 0.4089 - val_accuracy: 0.8376
# Epoch 20/30
# 787/787 [==============================] - 0s 374us/sample - loss: 0.3990 - accuracy: 0.8374 - val_loss: 0.4005 - val_accuracy: 0.8426
# Epoch 21/30
# 787/787 [==============================] - 0s 372us/sample - loss: 0.4050 - accuracy: 0.8297 - val_loss: 0.3927 - val_accuracy: 0.8477
# Epoch 22/30
# 787/787 [==============================] - 0s 365us/sample - loss: 0.4137 - accuracy: 0.8221 - val_loss: 0.3859 - val_accuracy: 0.8579
# Epoch 23/30
# 787/787 [==============================] - 0s 367us/sample - loss: 0.4275 - accuracy: 0.8196 - val_loss: 0.3798 - val_accuracy: 0.8629
# Epoch 24/30
# 787/787 [==============================] - 0s 369us/sample - loss: 0.4057 - accuracy: 0.8335 - val_loss: 0.3750 - val_accuracy: 0.8680
# Epoch 25/30
# 787/787 [==============================] - 0s 359us/sample - loss: 0.3855 - accuracy: 0.8297 - val_loss: 0.3721 - val_accuracy: 0.8731
# Epoch 26/30
# 787/787 [==============================] - 0s 373us/sample - loss: 0.3981 - accuracy: 0.8488 - val_loss: 0.3682 - val_accuracy: 0.8731
# Epoch 27/30
# 787/787 [==============================] - 0s 383us/sample - loss: 0.4036 - accuracy: 0.8424 - val_loss: 0.3638 - val_accuracy: 0.8731
# Epoch 28/30
# 787/787 [==============================] - 0s 373us/sample - loss: 0.3441 - accuracy: 0.8526 - val_loss: 0.3609 - val_accuracy: 0.8731
# Epoch 29/30
# 787/787 [==============================] - 0s 373us/sample - loss: 0.3688 - accuracy: 0.8653 - val_loss: 0.3571 - val_accuracy: 0.8782
# Epoch 30/30
# 787/787 [==============================] - 0s 372us/sample - loss: 0.3728 - accuracy: 0.8526 - val_loss: 0.3532 - val_accuracy: 0.8782
