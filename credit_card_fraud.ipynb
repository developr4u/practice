# %% [markdown]
# <a href="https://colab.research.google.com/github/developr4u/practice/blob/master/credit_card_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-rc0
# Out:
# Collecting tensorflow==2.0.0-rc0
#   Downloading https://files.pythonhosted.org/packages/fb/4b/77f0965ec7e8a76d3dcd6a22ca8bbd2b934cd92c4ded43fef6bea5ff3258/tensorflow-2.0.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (86.3MB)
#      |████████████████████████████████| 86.3MB 1.2MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.8.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.11.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.16.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (3.0.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (3.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.33.6)
# Collecting tf-estimator-nightly<1.14.0.dev2019080602,>=1.14.0.dev2019080601 (from tensorflow==2.0.0-rc0)
#   Downloading https://files.pythonhosted.org/packages/21/28/f2a27a62943d5f041e4a6fd404b2d21cb7c59b2242a4e73b03d9ba166552/tf_estimator_nightly-1.14.0.dev2019080601-py2.py3-none-any.whl (501kB)
#      |████████████████████████████████| 501kB 43.0MB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.0.8)
# Collecting tb-nightly<1.15.0a20190807,>=1.15.0a20190806 (from tensorflow==2.0.0-rc0)
#   Downloading https://files.pythonhosted.org/packages/bc/88/24b5fb7280e74c7cf65bde47c171547fd02afb3840cff41bcbe9270650f5/tb_nightly-1.15.0a20190806-py3-none-any.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 39.3MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (0.1.7)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc0) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==2.0.0-rc0) (41.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0.0-rc0) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (0.15.6)
# Installing collected packages: tf-estimator-nightly, tb-nightly, tensorflow
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed tb-nightly-1.15.0a20190806 tensorflow-2.0.0rc0 tf-estimator-nightly-1.14.0.dev2019080601

# %%
print(tf.__version__)
# Out:
# 2.0.0-rc0

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization,Conv1D,MaxPool1D
from tensorflow.keras.optimizers import Adam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

# %%
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud = data[data['Class']==1]
non_fraud = data[data['Class']==0]
fraud.shape,non_fraud.shape
# Out:
# ((492, 31), (284315, 31))

# %%
non_fraud = non_fraud.sample(492)

# %%
non_fraud.shape,fraud.shape
# Out:
# ((492, 31), (492, 31))

# %%
data = fraud.append(non_fraud,ignore_index=True)
data
# Out:
#          Time        V1        V2  ...       V28   Amount  Class
# 0       406.0 -2.312227  1.951992  ... -0.143276     0.00      1
# 1       472.0 -3.043541 -3.157307  ...  0.035764   529.00      1
# 2      4462.0 -2.303350  1.759247  ... -0.153029   239.93      1
# 3      6986.0 -4.397974  1.358367  ...  0.849573    59.00      1
# 4      7519.0  1.234235  3.019740  ...  0.146793     1.00      1
# 5      7526.0  0.008430  4.137837  ...  0.513574     1.00      1
# 6      7535.0  0.026779  4.132464  ...  0.496699     1.00      1
# 7      7543.0  0.329594  3.712889  ...  0.404474     1.00      1
# 8      7551.0  0.316459  3.809076  ...  0.402528     1.00      1
# 9      7610.0  0.725646  2.300894  ...  0.099372     1.00      1
# 10     7672.0  0.702710  2.426433  ...  0.129305     1.00      1
# 11     7740.0  1.023874  2.001485  ...  0.020206     1.00      1
# 12     7891.0 -1.585505  3.261585  ...  0.132817     1.00      1
# 13     8090.0 -1.783229  3.402794  ...  0.243746     1.00      1
# 14     8169.0  0.857321  4.093912  ...  0.148469     1.00      1
# 15     8408.0 -1.813280  4.917851  ...  0.569519     1.00      1
# 16     8415.0 -0.251471  4.313523  ...  0.572741     1.00      1
# 17     8451.0  0.314597  2.660670  ...  0.185030     1.00      1
# 18     8528.0  0.447396  2.481954  ...  0.175414     1.00      1
# 19     8614.0 -2.169929  3.639654  ...  0.298954     1.00      1
# 20     8757.0 -1.863756  3.442644  ...  0.208858     1.00      1
# 21     8808.0 -4.617217  1.695694  ...  0.890780     1.10      1
# 22     8878.0 -2.661802  5.856393  ...  0.303937     1.00      1
# 23     8886.0 -2.535852  5.793644  ...  0.308205     1.00      1
# 24     9064.0 -3.499108  0.258555  ... -0.900452  1809.68      1
# 25    11080.0 -2.125490  5.973556  ...  1.108933     1.00      1
# 26    11092.0  0.378275  3.914797  ...  0.411910     1.00      1
# 27    11131.0 -1.426623  4.141986  ...  0.711607     1.00      1
# 28    11629.0 -3.891192  7.098916  ...  0.875260     1.00      1
# 29    11635.0  0.919137  4.199633  ...  0.157851     1.00      1
# ..        ...       ...       ...  ...       ...      ...    ...
# 954  137132.0 -0.627400 -0.130067  ...  0.116180   147.72      0
# 955  146088.0 -1.227397 -1.101345  ...  0.183390    73.15      0
# 956   31456.0 -2.492067  1.734193  ...  0.012725    89.99      0
# 957   22896.0 -0.607386  0.651372  ... -0.150023     0.02      0
# 958   80541.0  1.235680 -0.039932  ...  0.009221     9.43      0
# 959  137683.0 -1.284396  0.885687  ... -0.029692     0.76      0
# 960  162935.0 -0.364608  0.999633  ... -0.339931     6.99      0
# 961   58635.0 -1.285573  0.762032  ...  0.035293     1.00      0
# 962   76135.0  1.204803  0.079821  ...  0.005831    25.70      0
# 963   26017.0 -0.789298  1.477566  ...  0.221848     1.98      0
# 964   70850.0 -0.476086 -0.090582  ...  0.046707    60.00      0
# 965  135842.0 -0.521987  1.744536  ... -0.037393    15.13      0
# 966   45875.0 -0.678003  1.220011  ...  0.169373     9.32      0
# 967  161938.0 -1.301373 -0.472371  ... -0.016689    78.58      0
# 968  110672.0 -0.511835  0.981861  ... -0.136005     2.15      0
# 969  115646.0  2.061676 -0.051468  ... -0.059895     1.79      0
# 970   85449.0  0.305984 -2.060763  ...  0.099372   477.73      0
# 971  142482.0  2.070926 -0.194546  ... -0.065548     1.98      0
# 972   47890.0 -0.177236 -2.606901  ...  0.132666   692.99      0
# 973  127720.0 -0.283087  0.788035  ...  0.183159    33.80      0
# 974   35130.0  0.750977 -1.421974  ...  0.069815   304.26      0
# 975  123032.0  2.247390 -0.755811  ... -0.062238    12.00      0
# 976  147111.0 -0.427325  0.309292  ... -0.100511     5.92      0
# 977  150201.0 -1.164986  1.386574  ...  0.174382     3.70      0
# 978  144878.0  1.963733 -1.830431  ... -0.039271   108.00      0
# 979   39286.0  1.562782 -1.229601  ...  0.015444    20.00      0
# 980  120359.0  2.140997 -1.092170  ... -0.039870    39.99      0
# 981  155211.0 -0.739221  1.596981  ...  0.368003     0.89      0
# 982  150022.0  2.079286 -0.005002  ... -0.092041     0.77      0
# 983   74670.0  1.146268 -0.696921  ... -0.007450    69.00      0
#
# [984 rows x 31 columns]

# %%
x = data.drop('Class',axis=1)
x.head()
# Out:
#      Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 0   406.0 -2.312227  1.951992 -1.609851  ...  0.177840  0.261145 -0.143276    0.00
# 1   472.0 -3.043541 -3.157307  1.088463  ... -0.145362 -0.252773  0.035764  529.00
# 2  4462.0 -2.303350  1.759247 -0.359745  ... -0.542628  0.039566 -0.153029  239.93
# 3  6986.0 -4.397974  1.358367 -2.592844  ... -0.657488 -0.827136  0.849573   59.00
# 4  7519.0  1.234235  3.019740 -4.304597  ...  0.566797 -0.010016  0.146793    1.00
#
# [5 rows x 30 columns]

# %%
y = data['Class']
y.value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0,stratify=y)
x_train.shape,x_test.shape
# Out:
# ((787, 30), (197, 30))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
x_train = x_train.reshape(787,30,1)
x_test = x_test.reshape(197,30,1)
x_train.shape,x_test.shape
# Out:
# ((787, 30, 1), (197, 30, 1))

# %%
model = Sequential()
model.add(Conv1D(32,(2),activation='relu',input_shape=(30,1)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv1D(64,(2),activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 29, 32)            96
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 29, 32)            128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 29, 32)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 28, 64)            4160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 64)            256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1792)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                114752
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=17,validation_data=(x_test,y_test),verbose=1)
# Out:
# Train on 787 samples, validate on 197 samples
# Epoch 1/17
# 787/787 [==============================] - 1s 2ms/sample - loss: 0.7861 - accuracy: 0.6493 - val_loss: 0.6281 - val_accuracy: 0.7817
# Epoch 2/17
# 787/787 [==============================] - 0s 383us/sample - loss: 0.5279 - accuracy: 0.7916 - val_loss: 0.5800 - val_accuracy: 0.8020
# Epoch 3/17
# 787/787 [==============================] - 0s 371us/sample - loss: 0.3994 - accuracy: 0.8526 - val_loss: 0.5432 - val_accuracy: 0.8782
# Epoch 4/17
# 787/787 [==============================] - 0s 383us/sample - loss: 0.3883 - accuracy: 0.8539 - val_loss: 0.5024 - val_accuracy: 0.8985
# Epoch 5/17
# 787/787 [==============================] - 0s 363us/sample - loss: 0.3374 - accuracy: 0.8729 - val_loss: 0.4627 - val_accuracy: 0.9137
# Epoch 6/17
# 787/787 [==============================] - 0s 356us/sample - loss: 0.2849 - accuracy: 0.8945 - val_loss: 0.4271 - val_accuracy: 0.9188
# Epoch 7/17
# 787/787 [==============================] - 0s 363us/sample - loss: 0.2741 - accuracy: 0.9047 - val_loss: 0.3950 - val_accuracy: 0.9086
# Epoch 8/17
# 787/787 [==============================] - 0s 365us/sample - loss: 0.3039 - accuracy: 0.8945 - val_loss: 0.3695 - val_accuracy: 0.9137
# Epoch 9/17
# 787/787 [==============================] - 0s 582us/sample - loss: 0.2764 - accuracy: 0.9047 - val_loss: 0.3440 - val_accuracy: 0.9188
# Epoch 10/17
# 787/787 [==============================] - 0s 356us/sample - loss: 0.2715 - accuracy: 0.8983 - val_loss: 0.3115 - val_accuracy: 0.9188
# Epoch 11/17
# 787/787 [==============================] - 0s 359us/sample - loss: 0.2310 - accuracy: 0.9098 - val_loss: 0.2929 - val_accuracy: 0.9239
# Epoch 12/17
# 787/787 [==============================] - 0s 367us/sample - loss: 0.2553 - accuracy: 0.9212 - val_loss: 0.2812 - val_accuracy: 0.9289
# Epoch 13/17
# 787/787 [==============================] - 0s 434us/sample - loss: 0.2260 - accuracy: 0.9174 - val_loss: 0.2734 - val_accuracy: 0.9188
# Epoch 14/17
# 787/787 [==============================] - 0s 382us/sample - loss: 0.2237 - accuracy: 0.9212 - val_loss: 0.2535 - val_accuracy: 0.9086
# Epoch 15/17
# 787/787 [==============================] - 0s 379us/sample - loss: 0.2139 - accuracy: 0.9212 - val_loss: 0.2257 - val_accuracy: 0.9036
# Epoch 16/17
# 787/787 [==============================] - 0s 371us/sample - loss: 0.1908 - accuracy: 0.9428 - val_loss: 0.2170 - val_accuracy: 0.8985
# Epoch 17/17
# 787/787 [==============================] - 0s 370us/sample - loss: 0.2121 - accuracy: 0.9314 - val_loss: 0.2069 - val_accuracy: 0.9036

# %%
epoch = 17
def plot_learning_curve(history,epoch):
  epoch_range = range(1,epoch+1)
  plt.plot(epoch_range,history.history['accuracy'])
  plt.plot(epoch_range,history.history['val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.title('Model Accuracy')
  plt.legend(['Train','Val'])
  plt.show()
  
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range,history.history['val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.title('Model Loss')
  plt.legend(['Train','Val'])
  plt.show()

# %%
plot_learning_curve(history,epoch)
